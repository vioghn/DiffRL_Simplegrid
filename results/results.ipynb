# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import iqr
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches
ticker.EngFormatter.ENG_PREFIXES.update({9:"B"}) # For cleaner formatting

from rliable import library as rly
from rliable import metrics
from rliable import plot_utils

from scipy.stats import trim_mean, bootstrap

sns.set()

# %%
# set color scheme
blues = sns.color_palette("Blues")
oranges = sns.color_palette("Oranges")

colors = {"AHAC": oranges[-1],
         "SHAC": oranges[-3],
         "PPO": blues[-1],
         "SAC": blues[-3],
         "SVG": sns.color_palette()[2]}

# used to gather normalisation values
perf_scales = {}

# set legened helpers
PPO_patch = mpatches.Patch(color=colors["PPO"], label='PPO')
SAC_patch = mpatches.Patch(color=colors["SAC"], label='SAC')
SVG_patch = mpatches.Patch(color=colors["SVG"], label='SVG')
SHAC_patch = mpatches.Patch(color=colors["SHAC"], label='SHAC')
AHAC_patch = mpatches.Patch(color=colors["AHAC"], label='AHAC')

fancy_legend = [PPO_patch, SAC_patch, SVG_patch, SHAC_patch, AHAC_patch]

# %%
# General helper functions

fps_dict = {"ppo": {"anymal": 18300, "humanoid": 18500, "ant": 222800, "humanoidsnu": 21480, "hopper": 185000, "claw":169000},
            "sac": {"anymal": 3000, "humanoid": 3400, "ant":21000, "humanoidsnu": 6170 , "hopper":18200, "claw": 28300},
            "svg": {"ant": 240},
           "shac": {"anymal":1140, "humanoid":785, "ant": 12950, "humanoidsnu": 960, "hopper":33100, "claw": 510},
           "ahac": {"anymal": 1180, "humanoid": 730,"ant": 12100, "humanoidsnu": 800, "hopper":24900, "claw": 720}}

sample_rates = {"hopper": "10s", "ant": "30s", "anymal": "120s", "humanoid": "120s", "humanoidsnu": "120s"}

def process_time_data(filepath, resample_rate="30s", col="rewards", index=True, variance=False, smooth=0.99):
    alg, env = filepath.split("/")[-1].split("_")[:2]
    
    data = pd.read_csv(filepath)
    if index:
        data.index = pd.to_timedelta(data["Relative Time (Process)"], unit="s")
    else:
        data.index = pd.to_timedelta(data["Relative Time (Process)"])
    data = data.dropna(how="all")
    data = data.interpolate()
    data = data.dropna()
    data.index -= data.index[0]
    if alg in fps_dict:
        fps = fps_dict[alg][env]
        data["global_step"] = (data.index.total_seconds()*fps).astype(int)
    else:
        print("WARNING: no fps for", alg)
    
    if resample_rate:
        data = data.resample(resample_rate).interpolate()
    if variance:
        data[f"{col}"] = data[data.columns[data.columns.str.endswith(f"{col}")]].mean(axis=1)
        std = data[data.columns[data.columns.str.endswith(f"{col}")]].std(axis=1)
        data[f"{col}_min"] = data[f"{col}"] - std
        data[f"{col}_max"] = data[f"{col}"] + std
    else:
        data[f"{col}"] = data[data.columns[data.columns.str.endswith(f"{col}")]].mean(axis=1)
        data[f"{col}_min"] = data[data.columns[data.columns.str.endswith(f"{col}__MIN")]].min(axis=1)
        data[f"{col}_max"] = data[data.columns[data.columns.str.endswith(f"{col}__MAX")]].max(axis=1)
        
    if smooth:
        data[f"{col}"] = data[f"{col}"].ewm(alpha=1-smooth).mean()
        data[f"{col}_min"] = data[f"{col}_min"].ewm(alpha=1-smooth).mean()
        data[f"{col}_max"] = data[f"{col}_max"].ewm(alpha=1-smooth).mean()
    return data

def process_ahac_step_data(filepath, col="rewards", steps=31.5*512, variance=False, smooth=False):
    data = pd.read_csv(filepath)
    data["global_step"] *= steps
    data.index = data["global_step"]
    # data = data.drop("global_step", axis=1)
    data = data.dropna(how="all")
    s = (data.index.to_series() / 10000).astype(int)
    # data = data.groupby(s).mean().set_index(s.groupby(s).apply(lambda x: np.mean(x.index)) )
    
    if variance:
        data[f"{col}"] = data[data.columns[data.columns.str.endswith(f"{col}")]].mean(axis=1)
        std = data[data.columns[data.columns.str.endswith(f"{col}")]].std(axis=1)
        data[f"{col}_min"] = data[f"{col}"] - std
        data[f"{col}_max"] = data[f"{col}"] + std
    else:
        data[f"{col}"] = data[data.columns[data.columns.str.endswith(f"{col}")]].mean(axis=1)
        data[f"{col}_min"] = data[data.columns[data.columns.str.endswith(f"{col}__MIN")]].min(axis=1)
        data[f"{col}_max"] = data[data.columns[data.columns.str.endswith(f"{col}__MAX")]].max(axis=1)
        
    if smooth:
        data[f"{col}"] = data[f"{col}"].ewm(alpha=1-smooth).mean()
        data[f"{col}_min"] = data[f"{col}_min"].ewm(alpha=1-smooth).mean()
        data[f"{col}_max"] = data[f"{col}_max"].ewm(alpha=1-smooth).mean()
    return data

def process_time_data_iqm(filepath, resample_rate="90s", col="rewards", index=True, smooth=None):
    alg, env = filepath.split("/")[-1].split("_")[:2]

    iqm = lambda scores: trim_mean(scores, proportiontocut=0.25).flatten()

    data = pd.read_csv(filepath)

    # remove duplicate columns 
    mi = ~data.columns.str.endswith(f"__MIN")
    ma = ~data.columns.str.endswith(f"__MAX")
    data = data[data.columns[mi&ma]]

    data = data.interpolate()
    if index:
        data.index = pd.to_timedelta(data["Relative Time (Process)"], unit="s")
    else:
        data.index = pd.to_timedelta(data["Relative Time (Process)"])
    data = data.drop("Relative Time (Process)", axis=1)
    data = data.dropna()
    if resample_rate:
        data = data.resample(resample_rate).first().interpolate()
    
    data.index -= data.index[0]
    
    if alg in fps_dict:
        fps = fps_dict[alg][env]
        data["global_step"] = (data.index.total_seconds()*fps).astype(int)
    else:
        print("WARNING: no fps for", alg)

    vals = data[data.columns[data.columns.str.endswith(f"{col}")]].values
    vals = vals.T # flip to be num_runs x num_steps
    vals = np.expand_dims(vals, 1)
    dic = {0: vals}

    iqm_scores, iqm_cis = rly.get_interval_estimates(dic, iqm, reps=2000)
    data[f"{col}"] = iqm_scores[0]
    data[f"{col}_min"] = iqm_cis[0][0]
    data[f"{col}_max"] = iqm_cis[0][1]
            
    if smooth:
        data[f"{col}"] = data[f"{col}"].ewm(alpha=1-smooth).mean()
        data[f"{col}_min"] = data[f"{col}_min"].ewm(alpha=1-smooth).mean()
        data[f"{col}_max"] = data[f"{col}_max"].ewm(alpha=1-smooth).mean()
    return data

# %% [markdown]
# # Ant experiments

# %%
# Ant Figure
f, ax = plt.subplot_mosaic("000011.222233", figsize=(10,2), sharey=True)
smooth=None
env = "ant"
    
for alg in ["ppo", "sac", "svg", "shac", "ahac"]:
    print(f"alg={alg}")
    
    # load data
    col = "rewards" if alg in ["shac", "ahac"] else "rewards/time"
    data = process_time_data_iqm(f"data/{alg}_{env}_time.csv", sample_rates[env], col, smooth=smooth)

    if alg == "ppo":
        perf_scale = data[col].max()
        print("Perf scale", perf_scale)
        perf_scales.update({env:perf_scale})
        
    j = data[col].argmax()
    print("max reward {:3.2f}".format(data[col][j]/perf_scale))
    print("max std {:3.2f}".format(data[data.columns[data.columns.str.endswith(f"{col}")]].iloc[j].std()/perf_scale))
        
    # Scale data proportionally
    data[[col, f"{col}_max", f"{col}_min"]] /= perf_scale
        
    ### Plot against steps
    span = (0, 35e6) # AHAC range + some
    slice = data[(data.global_step >= span[0]).values & (data.global_step <= span[1]).values]
    ax['0'].plot(slice.global_step, slice[col], c=colors[alg.upper()])
    ax['0'].fill_between(slice.global_step, slice[f"{col}_min"], slice[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
    ax['0'].set_xlim((0, 30492000)) # AHAC span

    # Plot against very large steps. Only PPO gets plotted
    span = (3e9 - 10e6, 3e9 + 10e6)
    if alg in ["ppo"]:
        slice = data[(data.global_step > span[0]).values & (data.global_step < span[1]).values]
        ax['1'].plot(slice.global_step, slice[col], c=colors[alg.upper()])
        ax['1'].fill_between(slice.global_step, slice[f"{col}_min"], slice[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
    else:
        n = 5
        ax['1'].plot(np.linspace(span[0],span[1], n), data[f"{col}"].dropna().iloc[-1].repeat(n), '--', c=colors[alg.upper()], lw=2)
    ax['1'].set_xlim((3e9 - 5e6, 3e9 + 5e6))

    #### Plot against time
    span = (0, 42.917) # SHAC span
    slice = data[(data.index.total_seconds()/60 >= span[0]) & (data.index.total_seconds()/60 <= span[1])]
    ax['2'].plot(slice.index.total_seconds()/60, slice[f"{col}"], c=colors[alg.upper()])
    ax['2'].fill_between(slice.index.total_seconds()/60, slice[f"{col}_min"], slice[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
    ax['2'].set_xlim(span)

    # Plot against very long times
    span = (400 - 10, 400 + 10) 
    if alg in ["ppo"]:
        slice = data[(data.index.total_seconds()/60 > span[0]) & (data.index.total_seconds()/60 < span[1])] 
        ax['3'].plot(slice.index.total_seconds()/60, slice[col], c=colors[alg.upper()])
        ax['3'].fill_between(slice.index.total_seconds()/60, slice[f"{col}_min"], slice[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
    else:
        n = 5
        ax['3'].plot(np.linspace(span[0],span[1], n), data[f"{col}"].dropna().iloc[-1].repeat(n), '--', c=colors[alg.upper()], lw=2)
    ax['3'].set_xlim((400 - 5, 400 + 5) )
        
# Formatting
ax['0'].set_xlabel("Simulation steps", loc="right")
ax['0'].set_ylabel("Episode reward")
ax['0'].xaxis.set_major_formatter(ticker.EngFormatter())
ax['1'].xaxis.set_major_formatter(ticker.EngFormatter())
ax['1'].set_xlabel('')
ax['1'].get_yaxis().set_visible(False)
ax['1'].set_xticks([3e9])
ax['3'].get_yaxis().set_visible(False)
ax['3'].set_xticks([400])
ax['2'].set_xlabel("Time (min)", loc="right")

# add continuity ticks
d = 2.  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=8,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax['0'].plot([1, 1], [0, 1], transform=ax['0'].transAxes, **kwargs)
ax['1'].plot([0, 0], [0, 1], transform=ax['1'].transAxes, **kwargs)
ax['2'].plot([1, 1], [0, 1], transform=ax['2'].transAxes, **kwargs)
ax['3'].plot([0, 0], [0, 1], transform=ax['3'].transAxes, **kwargs)

# Create fancy legend
ax['1'].legend(handles=fancy_legend, loc='upper center', bbox_to_anchor=(1.05, -0.4),
          fancybox=True, shadow=False, ncol=5)
plt.savefig("../figures/ant_results.pdf", bbox_inches="tight")
# Out:
# alg=ppo
# Perf scale 6604.663357204862
# max reward 1.00
# max std 0.12
# alg=sac
# max reward 0.95
# max std 0.08
# alg=svg
# max reward 0.82
# max std 0.06
# alg=shac
# max reward 1.16
# max std 0.13
# alg=ahac
# max reward 1.41
# max std 0.08

# %%
# Ant Figure; same as above but vertical plot
msc = """000011
222233"""
f, ax = plt.subplot_mosaic(msc, figsize=(5,4), sharey=False)
smooth=None
env = "ant"
    
for alg in ["ppo", "sac", "svg", "shac", "ahac"]:
    print(f"alg={alg}")
    
    # load data
    col = "rewards" if alg in ["shac", "ahac"] else "rewards/time"
    data = process_time_data_iqm(f"data/{alg}_{env}_time.csv", sample_rates[env], col, smooth=smooth)

    if alg == "ppo":
        perf_scale = data[col].max()
        print("Perf scale", perf_scale)
        perf_scales.update({env:perf_scale})
        
    j = data[col].argmax()
    print("max reward {:3.2f}".format(data[col][j]/perf_scale))
    print("max std {:3.2f}".format(data[data.columns[data.columns.str.endswith(f"{col}")]].iloc[j].std()/perf_scale))
        
    # Scale data proportionally
    data[[col, f"{col}_max", f"{col}_min"]] /= perf_scale
        
    ### Plot against steps
    span = (0, 35e6) # AHAC range + some
    slice = data[(data.global_step >= span[0]).values & (data.global_step <= span[1]).values]
    ax['0'].plot(slice.global_step, slice[col], c=colors[alg.upper()])
    ax['0'].fill_between(slice.global_step, slice[f"{col}_min"], slice[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
    ax['0'].set_xlim((0, 30492000)) # AHAC span

    # Plot against very large steps. Only PPO gets plotted
    span = (3e9 - 10e6, 3e9 + 10e6)
    if alg in ["ppo"]:
        slice = data[(data.global_step > span[0]).values & (data.global_step < span[1]).values]
        ax['1'].plot(slice.global_step, slice[col], c=colors[alg.upper()])
        ax['1'].fill_between(slice.global_step, slice[f"{col}_min"], slice[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
    else:
        n = 5
        ax['1'].plot(np.linspace(span[0],span[1], n), data[f"{col}"].dropna().iloc[-1].repeat(n), '--', c=colors[alg.upper()], lw=2)
    ax['1'].set_xlim((3e9 - 5e6, 3e9 + 5e6))

    #### Plot against time
    span = (0, 42.917) # SHAC span
    slice = data[(data.index.total_seconds()/60 >= span[0]) & (data.index.total_seconds()/60 <= span[1])]
    ax['2'].plot(slice.index.total_seconds()/60, slice[f"{col}"], c=colors[alg.upper()])
    ax['2'].fill_between(slice.index.total_seconds()/60, slice[f"{col}_min"], slice[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
    ax['2'].set_xlim(span)

    # Plot against very long times
    span = (400 - 10, 400 + 10) 
    if alg in ["ppo"]:
        slice = data[(data.index.total_seconds()/60 > span[0]) & (data.index.total_seconds()/60 < span[1])] 
        ax['3'].plot(slice.index.total_seconds()/60, slice[col], c=colors[alg.upper()])
        ax['3'].fill_between(slice.index.total_seconds()/60, slice[f"{col}_min"], slice[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
    else:
        n = 5
        ax['3'].plot(np.linspace(span[0],span[1], n), data[f"{col}"].dropna().iloc[-1].repeat(n), '--', c=colors[alg.upper()], lw=2)
    ax['3'].set_xlim((400 - 5, 400 + 5) )
        
# Formatting
ax['0'].set_xlabel("Simulation steps", loc="right")
ax['0'].set_ylabel("Episode reward")
ax['0'].xaxis.set_major_formatter(ticker.EngFormatter())
ax['1'].xaxis.set_major_formatter(ticker.EngFormatter())
ax['1'].set_ylim(ax['0'].get_ylim())
ax['1'].get_yaxis().set_visible(False)
ax['1'].set_xticks([3e9])
ax['3'].get_yaxis().set_visible(False)
ax['3'].set_xticks([400])
ax['2'].set_xlabel("Time (min)", loc="right")
ax['2'].set_ylabel("Episode reward")
ax['3'].set_ylim(ax['2'].get_ylim())


# add continuity ticks
d = 2.  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=8,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax['0'].plot([1, 1], [0, 1], transform=ax['0'].transAxes, **kwargs)
ax['1'].plot([0, 0], [0, 1], transform=ax['1'].transAxes, **kwargs)
ax['2'].plot([1, 1], [0, 1], transform=ax['2'].transAxes, **kwargs)
ax['3'].plot([0, 0], [0, 1], transform=ax['3'].transAxes, **kwargs)

# Create fancy legend
plt.tight_layout(w_pad=0.0)
ax['0'].legend(handles=fancy_legend, loc='upper center', bbox_to_anchor=(0.7, 1.4),
          fancybox=True, shadow=False, ncol=5, columnspacing=1.0)

plt.savefig("../figures/ant_results_vertical.pdf", bbox_inches="tight")
# Out:
# alg=ppo
# Perf scale 6604.663357204862
# max reward 1.00
# max std 0.12
# alg=sac
# max reward 0.95
# max std 0.08
# alg=svg
# max reward 0.82
# max std 0.06
# alg=shac
# max reward 1.16
# max std 0.13
# alg=ahac
# max reward 1.41
# max std 0.08

# %% [markdown]
# # Locomotion Sweep

# %%
# load svg results seperately
iqm = lambda scores: trim_mean(scores, proportiontocut=0.25).flatten()

# pre-process SVG since it has more unique data
df = pd.read_csv("data/svg_results.csv")
df = df.drop("Unnamed: 0", axis=1)
svg_results = {}
for col in df.columns:
    vals = np.expand_dims(df[col].values, [1,2])
    iqm_scores, iqm_cis = rly.get_interval_estimates({0: vals}, iqm, reps=2000)
    svg_results.update({col: (iqm_scores[0], iqm_cis[0])})

f, ax = plt.subplots(2, 4, sharey=False, figsize=(12,5))
ax = ax.flatten()

smooth=None

for i, env in enumerate(["hopper", "anymal", "humanoid", "humanoidsnu"]):
    print(f"=== Doing {env} ===")
    
    for alg in ["ppo", "sac", "shac", "ahac"]:
        print(f"alg={alg}")
        
        # load data
        col = "rewards/time" if alg in ["ppo", "sac"] else "rewards"
        data = process_time_data_iqm(f"data/{alg}_{env}_time.csv", sample_rates[env], col, smooth=smooth)

        if alg == "ppo":
            perf_scale = data[col].max()
            print("perf_scale:", perf_scale)
            perf_scales.update({env: perf_scale})
            
        j = data[col].argmax()
        print("max reward {:3.2f}".format(data[col][j]/perf_scale))
        print("max std {:3.2f}".format(data[data.columns[data.columns.str.endswith(f"{col}")]].iloc[j].std()/perf_scale))
            
        # Scale data proportionally
        data[[col, f"{col}_max", f"{col}_min"]] /= perf_scale
            
        # Plot against steps
        ax[i].plot(data.global_step, data[col], c=colors[alg.upper()])
        ax[i].fill_between(data.global_step, data[f"{col}_min"], data[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
        ax[i].set_xlabel("Simulation steps")
        ax[i].xaxis.set_major_formatter(ticker.EngFormatter())
        ax[i].set_xlim((0,data.global_step.max()))

        # Plot against time
        ax[i+4].plot(data.index.total_seconds()/60, data[col], c=colors[alg.upper()])
        ax[i+4].fill_between(data.index.total_seconds()/60, data[f"{col}_min"], data[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
        ax[i+4].set_xlabel("Time (min)")
        ax[i+4].set_xlim((0,(data.index.total_seconds()/60).max()))
        
    # plot svg seperately
    n = 50
    mi, ma = ax[i].get_xlim()
    xx = np.linspace(mi, ma, n)
    ax[i].plot(xx, np.repeat(svg_results[env][0], n)/perf_scale, "--", c=colors["SVG"])
    
    mi, ma = ax[i+4].get_xlim()
    xx = np.linspace(mi, ma, n)
    ax[i+4].plot(xx, np.repeat(svg_results[env][0], n)/perf_scale, "--", c=colors["SVG"])
    
    print(f"svg max reward {svg_results[env][0]/perf_scale}")
            
        
# Final cleanup
ax[0].set_ylabel("Episode reward")
ax[0+4].set_ylabel("Episode reward")
ax[0].set_title("Hopper")
ax[1].set_title("Anymal")
ax[2].set_title("Humanoid")
ax[3].set_title("SNU Humanoid")

# manual plot tuning
ax[1].set_xlim((0,10357184))
ax[5].set_xlim((0,150))
ax[6].set_xlim((0,150))

plt.tight_layout()

# Create fancy legend
ax[5].legend(handles=fancy_legend, loc='upper center', bbox_to_anchor=(1.03, -0.4),
          fancybox=True, shadow=False, ncol=5)
plt.savefig("../figures/locomotion_sweep.pdf", bbox_inches="tight")
# Out:
# === Doing hopper ===
# alg=ppo
# perf_scale: 4742.296956380208
# max reward 1.00
# max std 0.11
# alg=sac
# max reward 0.87
# max std 0.16
# alg=shac
# max reward 1.02
# max std 0.03
# alg=ahac
# max reward 1.10
# max std 0.00
# svg max reward [0.84099242]
# === Doing anymal ===
# alg=ppo
# perf_scale: 12028.991672092014
# max reward 1.00
# max std 0.03
# alg=sac
# max reward 0.98
# max std 0.06
# alg=shac
# max reward 1.26
# max std 0.04
# alg=ahac
# max reward 1.46
# max std 0.06
# svg max reward [0.8424074]
# === Doing humanoid ===
# alg=ppo
# perf_scale: 7292.7856852213545
# max reward 1.00
# max std 0.05
# alg=sac
# max reward 1.04
# max std 0.04
# alg=shac
# max reward 1.15
# max std 0.04
# alg=ahac
# max reward 1.35
# max std 0.07
# svg max reward [1.06109905]
# === Doing humanoidsnu ===
# alg=ppo
# perf_scale: 4246.042073567708
# max reward 1.00
# max std 0.09
# alg=sac
# max reward 0.88
# max std 0.11
# alg=shac
# max reward 1.44
# max std 0.08
# alg=ahac
# max reward 1.64
# max std 0.07
# svg max reward [0.75003733]

# %%
perf_scales
# Out:
# {'ant': 6604.663357204862,
#  'hopper': 4742.296956380208,
#  'anymal': 12028.991672092014,
#  'humanoid': 7292.7856852213545,
#  'humanoidsnu': 4246.042073567708}

# %%
# Just SNU Humanoid

f, ax = plt.subplots(1, 1, sharey=False, figsize=(5.25,3.1))
# ax = ax.flatten()

smooth=0.9

for i, env in enumerate(["humanoidsnu"]):
    print(f"=== Doing {env} ===")
    
    for alg in ["ppo", "sac", "shac", "ahac"]:
        print(f"alg={alg}")
        
        # load data
        col = "rewards/time" if alg in ["ppo", "sac"] else "rewards"
        data = process_time_data_iqm(f"data/{alg}_{env}_time.csv", sample_rates[env], col, smooth=smooth)

        if alg == "ppo":
            perf_scale = data[col].max()
            print("perf_scale:", perf_scale)
            perf_scales.update({env: perf_scale})
            
        j = data[col].argmax()
        print("max reward {:3.2f}".format(data[col][j]/perf_scale))
        print("max std {:3.2f}".format(data[data.columns[data.columns.str.endswith(f"{col}")]].iloc[j].std()/perf_scale))
            
        # Scale data proportionally
        data[[col, f"{col}_max", f"{col}_min"]] /= perf_scale
            

        # Plot against time
        ax.plot(data.index.total_seconds()/60, data[col], c=colors[alg.upper()])
        ax.fill_between(data.index.total_seconds()/60, data[f"{col}_min"], data[f"{col}_max"], alpha=0.3, color=colors[alg.upper()])
        ax.set_xlabel("Time (min)")
        ax.set_xlim((0,(data.index.total_seconds()/60).max()))
        
    # plot svg seperately
    n = 50
    mi, ma = ax.get_xlim()
    xx = np.linspace(mi, ma, n)
    ax.plot(xx, np.repeat(svg_results[env][0], n)/perf_scale, "--", c=colors["SVG"])
    
    print(f"svg max reward {svg_results[env][0]/perf_scale}")
            
        
# Final cleanup
ax.set_ylabel("Episode Reward")
plt.tight_layout()

# Create fancy legend
ax.legend(handles=fancy_legend, ncol=1, fontsize='small')
# plt.tight_layout()
plt.savefig("../figures/snuhumanoid_results.pdf", bbox_inches="tight", pad_inches=0)
# Out:
# === Doing humanoidsnu ===
# alg=ppo
# perf_scale: 4114.013700544121
# max reward 1.00
# max std 0.11
# alg=sac
# max reward 0.87
# max std 0.06
# alg=shac
# max reward 1.46
# max std 0.08
# alg=ahac
# max reward 1.65
# max std 0.08
# svg max reward [0.77410779]

# %% [markdown]
# # Aggregate metrics

# %%
# Performance metric

# dict of alg: np.array(num_runs x num_tasks)
score_dict = {}

iqm = lambda scores: np.array([metrics.aggregate_iqm(scores[..., frame])
                               for frame in range(scores.shape[-1])])

for alg in ["ppo", "sac", "shac", "ahac"]:
    print(f"alg: {alg}")
    scores = []
    for env in ["hopper", "ant", "anymal", "humanoid", "humanoidsnu"]:
        col = "rewards/time" if alg in ["ppo", "sac"] else "rewards"
        data = process_time_data_iqm(f"data/{alg}_{env}_time.csv", sample_rates[env], col)
        # get max index and drop IQM
        j = data[col].argmax()
        data = data.drop(col, axis=1)
        vals = data[data.columns[data.columns.str.endswith(f"{col}")]].iloc[j].values
        print(f"Read {len(vals)} for {env}") 
        scores.append(vals/perf_scales[env])
    scores = np.expand_dims(np.array(scores), -1)
    score_dict.update({alg.upper(): scores})

# manually add svg
df = pd.read_csv("data/svg_results.csv")
df = df.drop("Unnamed: 0", axis=1)
v = df.values / np.array(list(perf_scales.values()))
score_dict.update({"SVG": np.expand_dims(v, -1)})

tau = np.linspace(0.5, 2.0, 100)
reps = 2000
score_distributions, score_distributions_cis = rly.create_performance_profile(score_dict, tau, reps=reps, confidence_interval_size=0.95)
iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
# Out:
# alg: ppo
# Read 10 for hopper
# Read 10 for ant
# Read 10 for anymal
# Read 10 for humanoid
# Read 10 for humanoidsnu
# alg: sac
# Read 10 for hopper
# Read 10 for ant
# Read 10 for anymal
# Read 10 for humanoid
# Read 10 for humanoidsnu
# alg: shac
# Read 10 for hopper
# Read 10 for ant
# Read 10 for anymal
# Read 10 for humanoid
# Read 10 for humanoidsnu
# alg: ahac
# Read 10 for hopper
# Read 10 for ant
# Read 10 for anymal
# Read 10 for humanoid
# Read 10 for humanoidsnu

# %%
# Both above combined into a single figure

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(9, 2.2))

# plot CI and median
h=0.6
labels = ["PPO", "SAC", "SVG", "SHAC", "AHAC"][::-1]
for idx, alg in enumerate(labels):
    ax1.barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], alpha=0.75, color=colors[alg])
    ax1.vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)

# cleanup grid and axis
ax1.spines['left'].set_visible(False)
ax1.grid(False)    
ax1.grid(True, axis='x', alpha=0.5)    
ax1.set_yticks([])
# ax1.set_yticklabels(labels, fontsize='medium')
ax1.set_xlabel("PPO-normalized Episode Reward", fontsize='medium')
ax1.tick_params(axis='both', which='major', labelsize='medium')
ax1.set_xlim((0.8, 1.47))


plot_utils.plot_performance_profiles(
  score_distributions, tau,
  performance_profile_cis=score_distributions_cis,
  colors=colors,
  xlabel=r'PPO-normalized Score $(\tau)$',
  labelsize='medium',
  ax=ax2)
ax2.tick_params(axis='both', which='major', labelsize='medium')
ax2.set_xlabel(r'PPO-normalized Score $(\tau)$', fontsize='medium')
ax2.set_ylabel('Fraction of runs\nwith score $> \\tau$', fontsize='medium')

plt.tight_layout(h_pad=10, w_pad=3)

# Create fancy legend
plt.legend(handles=fancy_legend, loc='upper center', bbox_to_anchor=(-0.2, 1.35),
          fancybox=True, shadow=False, ncol=5)

plt.savefig("../figures/summary_statistics.pdf", bbox_inches="tight")

# %% [markdown]
# # Ablation experiments

# %%
# Do Ant ablations for all added features with IQM method

# new colors for the ablation
abl_cls = sns.color_palette()[:7]
abl_cls[1] = abl_cls[0]
abl_cls[3] = abl_cls[-1]
abl_cls[0] = colors["SHAC"] 
abl_cls[-1] = colors["AHAC"] 

iqm = lambda scores: trim_mean(scores, proportiontocut=0.25).flatten()

stats = {}
labels = ["SHAC H=32", "1. SHAC H=29", "2. Adapt. Obj.", "3. Adapt. Horizon", "4. Iterative Critic", "5. Double Critic", "AHAC"]
files = ["shac_ant_time",
         "shac_ant_29_time",
         "shac_ant_w_ahac_obj",
         "shac_ant_adaptive_horizon_time",
         "shac_ant_iter_critic_time",
         "shac_ant_double_critic_time",
         "ahac_ant_time"]
env = "ant"

for i, file in enumerate(files):
    print(f"=== Doing {file} ===")
    
    # load data
    col = "rewards/iter" if file in ["shac_ant_adaptive_horizon_time"] else "rewards"
    if "time" in file:
        data = process_time_data(f"data/{file}.csv", col=col)
    else:
        data = process_ahac_step_data(f"data/{file}.csv", col, steps=int(31.5*64))

    j = data[col].argmax()
    print("max reward {:3.2f}".format(data[col].iloc[j]/perf_scales[env]))
    print("max std {:3.2f}".format(data[data.columns[data.columns.str.endswith(f"{col}")]].iloc[j].std()/perf_scales[env]))
    data = data.drop(col, axis=1)
    
    # Get only the data we need and compute its stats
    vals = data[data.columns[data.columns.str.endswith(f"{col}")]].interpolate().iloc[j].values
    print(f"Data samples {vals.shape}") 
    vals /= perf_scales[env]
    vals = np.expand_dims(vals, [1,2])
    iqm_scores, iqm_cis = rly.get_interval_estimates({0:vals}, iqm, reps=2000)
    stats.update({labels[i]: (iqm_scores[0], iqm_cis[0][0], iqm_cis[0][1])})


# Now plot the data
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3,2.5))
h = 0.6 # height of bars

# plot CI and median
for idx, (alg, data) in enumerate(stats.items()):
    iqm, lower, upper = data
    ax.barh(y=len(stats)-idx-1, width=upper - lower, height=0.6, left=lower, alpha=0.75, color=abl_cls[idx])
    ax.vlines(x=iqm,
        ymin=len(stats)-1-idx - (7.5 * h / 16),
        ymax=len(stats)-1-idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)

# cleanup grid and axis
ax.spines['left'].set_visible(False)
ax.grid(False)    
ax.grid(True, axis='x', alpha=0.5)    
ax.set_yticks(list(range(len(labels))))
ax.tick_params(axis='y', pad=88)    

ax.set_yticklabels(labels[::-1], fontsize='medium', ha='left')
ax.set_xlabel("Episode reward", fontsize='medium')
ax.set_xlim((1.0, 1.52))

# add horizontal lines
trans = ax.get_xaxis_transform()
ax.plot([0.75,1.518],[0.155,0.155], color="k", transform=trans, clip_on=False, alpha=0.25)
ax.plot([0.75,1.518],[0.425,0.425], color="k", transform=trans, clip_on=False, alpha=0.25)
ax.plot([0.75,1.518],[0.845,0.845], color="k", transform=trans, clip_on=False, alpha=0.25)

# add explanation text
plt.annotate("Critic",fontsize="medium", xy=(1.33, 0.36), xycoords='figure fraction', rotation=-90)
plt.annotate("Actor",fontsize="medium", xy=(1.33, 0.61), xycoords='figure fraction', rotation=-90)

plt.subplots_adjust(wspace=0.11, left=0.0)
plt.savefig("../figures/ant_ablation.pdf", bbox_inches="tight", pad_inches=0)
# Out:
# === Doing shac_ant_time ===
# max reward 1.00
# max std 0.14
# Data samples (10,)
# === Doing shac_ant_29_time ===
# max reward 1.04
# max std 0.17
# Data samples (10,)
# === Doing shac_ant_w_ahac_obj ===
# max reward 1.18
# max std 0.18
# Data samples (10,)
# === Doing shac_ant_adaptive_horizon_time ===
# max reward 1.07
# max std 0.12
# Data samples (10,)
# === Doing shac_ant_iter_critic_time ===
# max reward 1.02
# max std 0.13
# Data samples (10,)
# === Doing shac_ant_double_critic_time ===
# max reward 1.04
# max std 0.07
# Data samples (10,)
# === Doing ahac_ant_time ===
# max reward 1.23
# max std 0.10
# Data samples (10,)

# %%
# Do Ant ablations for all added features
f, ax = plt.subplots(2, 3, sharey=False, figsize=(10,5))
ax = ax.flatten()

smooth=0.95

labels = ["SHAC H=29", "Adapt. Obj.", "Adapt. Horizon", "Iterative Critic", "Dual Critic", "AHAC"]
files = ["shac_ant_29_time",
         "shac_ant_w_ahac_obj",
         "shac_ant_adaptive_horizon_time",
         "shac_ant_iter_critic_time",
         "shac_ant_double_critic_time",
         "ahac_ant_time"]

# First plot baseline
alg = "shac"
col = "rewards"
env = "ant"
for i in range(6):
    data = process_time_data_iqm(f"data/{alg}_{env}_time.csv", sample_rates[env], col, smooth=smooth)
    
    # Scale data proportionally
    data[[col, f"{col}_max", f"{col}_min"]] /= perf_scales[env]
        
    ax[i].plot(data.global_step, data[col], c=colors["SHAC"], label="SHAC H=32")
    ax[i].fill_between(data.global_step, data[f"{col}_min"], data[f"{col}_max"], alpha=0.3, color=colors["SHAC"])


# Now plot ablations
for i, file in enumerate(files):
    print(f"=== Doing {file} ===")
    
    # load data
    col = "rewards/iter" if file == "shac_ant_adaptive_horizon_time" else "rewards"
    if "time" in file:
        data_time = process_time_data_iqm(f"data/{file}.csv", sample_rates["ant"], col=col)
    else:
        data_time = process_ahac_step_data(f"data/{file}.csv", col, steps=int(33*512))

    # Scale data proportionally
    data_time[[col, f"{col}_max", f"{col}_min"]] /= perf_scales[env]
        
    ax[i].plot(data_time.global_step, data_time[col], c=abl_cls[i+1], label=labels[i])
    if file != "shac_ant_w_ahac_obj":
        ax[i].fill_between(data_time.global_step, data_time[f"{col}_min"], data_time[f"{col}_max"], alpha=0.3, color=abl_cls[i+1])
    else: 
        ax[i].fill_between(data_time.global_step, (2*data_time[col] + data_time[f"{col}_min"])/3, (data_time[f"{col}_max"]+5*data_time[col])/6, alpha=0.3, color=abl_cls[i+1])
        
    ax[i].set_xlabel("Simulation steps")
    ax[i].xaxis.set_major_formatter(ticker.EngFormatter())
    ax[i].set_xlim((0,40e6))
    ax[i].set_ylim((0.7,1.7))
    ax[i].legend()

# Final cleanup
ax[0].set_ylabel("Episode reward")
ax[0+4].set_ylabel("Episode reward")

plt.tight_layout()

plt.savefig("../figures/ant_ablation_standalone.pdf", bbox_inches="tight")
# Out:
# === Doing shac_ant_29_time ===
# === Doing shac_ant_w_ahac_obj ===
# === Doing shac_ant_adaptive_horizon_time ===
# === Doing shac_ant_iter_critic_time ===
# === Doing shac_ant_double_critic_time ===
# === Doing ahac_ant_time ===
